# %% [markdown]
# # <center>Computer Application in Engineering Design Lab
# ## <center>Lab 14, BCE Fall 2021
# ### Instructor: Muhammad Farooq Khan
# ### Date: 26-Dec-2021
# ### Open Ended Lab

# %% [markdown]
# ### Task 1

# %%
print("Scatter Plot\n")
import matplotlib.pyplot as plt
import numpy as np

X,Y = np.loadtxt(r'''C:\\Users\\UMAR\\Desktop\\OEL\\ex1data1.txt''', delimiter=',', unpack=True)
plt.scatter(X, Y)
plt.show()

print("\nAdditional Graph\n")
plt.bar(X, Y)
plt.title('Line Graph')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# Scatter Plot
# Additional Graph
